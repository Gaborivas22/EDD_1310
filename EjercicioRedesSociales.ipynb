# %%
'''Autor: Gabriel Rivas Maldonado
   Estructura de Datos
   Grupo: 1310'''

import pandas as pd #importamos librerias
import numpy as np

chart_data=pd.read_csv('presenciaredes.csv')#Accedemos al archivo

p = np.asarray(chart_data)#Transformamos el archivo en un array

print(chart_data)#Imprimimos por primera vez la tabla
print("\n")

junio=chart_data.loc[[7],["ENERO","JUNIO"]]#Mostramos la diferencia de followers
print(junio)
print("\n")
enero=int(p[7][3])
junio=int(p[7][8])
resultado=enero-junio
diferencia=np.abs(resultado)
print("Entre Enero y Junio existio esta diferencia de followers en twitter:")
print(diferencia)
print("")

#Mostramos la diferencia de visualizaciones entre los meses seleccionados
opcion1=str(input("De que 1er mes deseas ver la diferencia? Por favor escribelo todo en mayusculas"))
opcion2=str(input("De que 2do mes deseas ver la diferencia? Por favor escribelo todo en mayusculas"))
meses=chart_data.loc[[15],[opcion1,opcion2]]
print(meses)
print("\n")

#Calculamos el promedio de crecimiento en Twitter 
mesesTwitter=int(p[8][3])+int(p[8][4])+int(p[8][5])+int(p[8][6])+int(p[8][7])+int(p[8][8])
promedioTwitter=mesesTwitter/6
print("El promedio de crecimiento de Twitter es de: ", promedioTwitter)

#Calculamos el promedio de crecimiento en Facebook
mesesFeisbu = int(p[1][3])+int(p[1][4])+int(p[1][5])+int(p[1][6])+int(p[1][7])+int(p[1][8])
promedioFeisbu = mesesFeisbu/6
print("El promedio de crecimiento de Facebook es de: ", promedioFeisbu)
# Out:
#    RED SOCIAL                    CONCEPTO   AÑO   ENERO FEBRERO   MARZO  \
# 0    FACEBOOK                  SEGUIDORES  2020  152107  156957  160595
# 1    FACEBOOK    CRECIMIENTO (SEGUIDORES)  2020     660    4850    3638
# 2    FACEBOOK  PORCENTAJE DE CRECIMIENTO   2020   0.43%      3%      2%
# 3    FACEBOOK              PUBLICACIONES   2020      45      53      52
# 4    FACEBOOK  ME GUSTA EN PUBLICACIONES   2020    8771    9002   13556
# 5    FACEBOOK  PUBLICACIONES COMPARTIDAS   2020    2338    2680    2802
# 6    FACEBOOK      COMENTARIOS (USUARIOS)  2020     902     601     775
# 7     TWITTER      SEGUIDORES (FOLLOWERS)  2020   62404   63232   64149
# 8     TWITTER    CRECIMIENTO DE FOLLOWERS  2020     863     828     917
# 9     TWITTER   PORCENTAJE DE CRECIMIENTO  2020      1%      1%      1%
# 10    TWITTER              PUBLICACIONES   2020      77      84      90
# 11    TWITTER                     RETUITS  2020     563     601     748
# 12    TWITTER                    ME GUSTA  2020    1224    1225    1601
# 13    TWITTER                    IMPACTOS  2020  197275  220118  270310
# 14    YOUTUBE                      VIDEOS  2020       1       2       5
# 15    YOUTUBE             VISUALIZACIONES  2020   12226   15605   19602
# 16    YOUTUBE                 COMENTARIOS  2020       0       0       2
# 17    YOUTUBE                    ME GUSTA  2020       4      15      15
#
#      ABRIL    MAYO   JUNIO JULIO AGOSTO SEPTIEMBRE OCTUBRE NOVIEMBRE  \
# 0   165180  170488  178413     0      0          0       0         0
# 1     4585    5308    7925     0      0          0       0         0
# 2       3%      3%      4%    0%     0%         0%      0%        0%
# 3      106      98      64     0      0          0       0         0
# 4    15022   38953   16487     0      0          0       0         0
# 5     4214    8415    4240     0      0          0       0         0
# 6     1100    2614    1268     0      0          0       0         0
# 7    65410   66355   67496     0      0          0       0         0
# 8     1261     945    1141     0      0          0       0         0
# 9       2%      1%      1%    0%     0%         0%      0%        0%
# 10     135     127      82     0      0          0       0         0
# 11     847    1136     780     0      0          0       0         0
# 12    1994    2667    2069     0      0          0       0         0
# 13  311931  409684  284147     0      0          0       0         0
# 14       4       4       4     0      0          0       3         5
# 15   19452   21805   17344     0      0          0       0         0
# 16       0       6       0     0      0          0       1         3
# 17       8      30      33     0      0          0       8        23
#
#    DICIEMBRE  Unnamed: 15
# 0          0          NaN
# 1          0          NaN
# 2         0%          NaN
# 3          0          NaN
# 4          0          NaN
# 5          0          NaN
# 6          0          NaN
# 7          0          NaN
# 8          0          NaN
# 9         0%          NaN
# 10         0          NaN
# 11         0          NaN
# 12         0          NaN
# 13         0          NaN
# 14         0          NaN
# 15         0          NaN
# 16         0          NaN
# 17         0          NaN
#
#
#    ENERO  JUNIO
# 7  62404  67496
#
#
# Entre Enero y Junio existio esta diferencia de followers en twitter:
# 5092
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-136-35230821b4bd> in <module>
#      24 print("")
#      25
# ---> 26 opcion1=str(input("De que 1er mes deseas ver la diferencia? Por favor escribelo todo en mayusculas"))
#      27 opcion2=str(input("De que 2do mes deseas ver la diferencia? Por favor escribelo todo en mayusculas"))
#      28 meses=chart_data.loc[[15],[opcion1,opcion2]]
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
